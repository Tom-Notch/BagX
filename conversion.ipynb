# %%
! echo $SHELL
! source /opt/ros/noetic/setup.zsh
# Out:
# /usr/bin/zsh
# /opt/ros/noetic/etc/catkin/profile.d/50-rosmon.zsh:66: command not found: compdef

# %%
import gi
gi.require_version('Gst', '1.0')
from gi.repository import Gst
from sensor_msgs.msg import Image
import cv2
import numpy as np
import os
import re
import rosbag
import rospy
import time
import threading
import yaml

# %%
file_type_to_extension = {
    "mp4": ".mp4",
    "rosbag": ".bag",
    "directory": "",
    "YAML": ".yaml"
}

# %%
def load_config(cfg_path: str) -> dict:
    with open(cfg_path) as f:
        cfg: dict = yaml.safe_load(f)
    return cfg

def print_dict(d: dict, indent: int = 0):
    for key, value in d.items():
        if isinstance(value, dict):
            print('  ' * indent + str(key) + ": ")
            print_dict(value, indent+1)
        else:
            print('  ' * indent + str(key) + ": " + str(value))

# %%
class ImgDirOutput:
    def __init__(self, name: str, output: dict):
        self.name = name
        self.path = output['path']
        self.directory = output['directory']

        assert output['type'] == 'directory', f'{self.name}\'s output type {output["type"]} is inappropriate for ImgDirOutput Class.'

    def callback(self, image, time_stamp: int) -> None:
        output_image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        cv2.imwrite(os.path.join(self.directory, str(time_stamp) + '.png'), output_image)

    def close(self) -> None:
        pass

# %%
class RosbagOutput:
    def __init__(self, name: str, output: dict):
        self.name = name
        self.path = output['path']
        self.directory = output['directory']
        self.topic = output['topic']
        self.frame_id = output.get('frame_id', None)

        assert output['type'] == 'rosbag', f'{self.name}\'s output type {output["type"]} is inappropriate for RosbagOutput Class.'

        self.init_rosbag()

    def init_rosbag(self) -> None:
        self.bag = rosbag.Bag(self.path, 'w')
        
        self.image_msg = Image()
        if self.frame_id is not None:
            self.image_msg.header.frame_id = self.frame_id
        self.image_msg.encoding = 'rgb8'
        self.image_msg.header.seq = -1

    def callback(self, image, time_stamp: int) -> None:
        self.image_msg.header.stamp = rospy.Time(secs=int(time_stamp // 1e9), nsecs=int(time_stamp % 1e9))
        self.image_msg.header.seq += 1
        self.image_msg.height = image.shape[0]
        self.image_msg.width = image.shape[1]
        self.image_msg.step = self.image_msg.width * 3
        self.image_msg.data = image.tobytes()

        self.bag.write(self.topic, self.image_msg, t=self.image_msg.header.stamp)

    def close(self) -> None:
        self.bag.close()

# %%
class MP4Input:
    def __init__(self, name: str, input: dict, outputs: dict):
        """initialize the MP4Input class

        Args:
            name (str): name of this pipeline in the yaml config, used in named sink of gstreamer pipeline
            input (dict): input config
            output (list): list of output class instances, this input class only uses their callback functions
        """
        Gst.init(None)
        self.name = name
        self.path = input['path']
        if not input['type'] == 'mp4': # verify type is correct
            raise ValueError(f'Input type {input["type"]} is inappropriate for MP4Input Class.')

        self.width = input.get('width', None)
        self.height = input.get('height', None)
        self.start = input.get('start', None)
        self.end = input.get('end', None)
        self.output_callbacks = [output.callback for output in outputs.values()]
        self.close_handlers = [output.close for output in outputs.values()]

        self.setup()

    def setup(self):
        self.parse_start_time()

        self.bytes_per_pixel = 3 # since it's in RGB format
        self.current_relative_time = 0

        # setup gstreamer pipeline
        self.gstreamer_pipeline_str = "filesrc location=" + self.path + " ! decodebin ! nvvideoconvert ! video/x-raw,format=RGB"
        if self.width:
            self.gstreamer_pipeline_str += ",width=" + str(self.width)
        if self.height:
            self.gstreamer_pipeline_str += ",height=" + str(self.height)
        self.gstreamer_pipeline_str += " ! progressreport update-freq=1 name=" + self.name + "_progress ! fakesink name=" + self.name
        print(self.name + " MP4Input's gstreamer pipeline string: " + self.gstreamer_pipeline_str)
        self.gstreamer_pipeline = Gst.parse_launch(self.gstreamer_pipeline_str)
        self.gstreamer_pipeline.get_by_name(self.name).get_static_pad('sink').add_probe(Gst.PadProbeType.BUFFER, self.callback)

    def parse_start_time(self):
        """parse the absolute start time in nanoseconds from the file name
        """
        match = re.search(r'(\d{10}_\d{9})(?=\.\w+$)', self.path)
        assert match is not None, f'{self.path} does not contain the proper timestamp sub-string.'
        time_str = match[1].split('_')
        self.absolute_start_time = int(time_str[0]) * int(1e9) + int(time_str[1])

    def callback(self, pad, info):
        buffer = info.get_buffer()

        image = self.get_image(buffer, pad.get_current_caps())

        self.current_relative_time = buffer.pts

        # check if the current frame is within the start and end time
        if (self.start and self.current_relative_time * 1e-9 < self.start) or (self.end and self.current_relative_time * 1e-9 > self.end):
            return Gst.PadProbeReturn.OK

        current_absolute_time = self.absolute_start_time + self.current_relative_time

        # calling callbacks for each output pipeline
        for callback in self.output_callbacks:
            callback(image, current_absolute_time)

        return Gst.PadProbeReturn.OK

    def get_image(self, buffer, caps):
        caps_structure = caps.get_structure(0)
        height, width = caps_structure.get_value('height'), caps_structure.get_value('width')

        is_mapped, map_info = buffer.map(Gst.MapFlags.READ)
        if is_mapped:
            try:
                return np.ndarray((height, width, self.bytes_per_pixel), dtype='uint8', buffer=map_info.data).copy() # extend array lifetime beyond subsequent unmap
            finally:
                buffer.unmap(map_info)

    def loop(self):
        self.gstreamer_pipeline.set_state(Gst.State.PLAYING)

        try:
            while True:
                msg = self.gstreamer_pipeline.get_bus().timed_pop_filtered(Gst.SECOND * 5, Gst.MessageType.EOS | Gst.MessageType.ERROR) #! 5 seconds timeout

                if msg:
                    if msg.type == Gst.MessageType.EOS:
                        break
                    elif msg.type == Gst.MessageType.ERROR:
                        raise Exception('GStreamer stream Error occurred in pipeline: ' + self.name)

                # # Query position and duration to display progress
                # success, position = self.gstreamer_pipeline.query_position(Gst.Format.TIME)
                # success, duration = self.gstreamer_pipeline.query_duration(Gst.Format.TIME)

                # if success and duration != Gst.CLOCK_TIME_NONE and duration != 0:
                #     progress = (position / duration) * 100
                #     print(f"{self.name}\'s progress: {progress:.2f}%")

                #! delay for 5 seconds since the progress query is blocking
                time.sleep(1)
        finally:
            self.gstreamer_pipeline.set_state(Gst.State.NULL)

            # call close handlers for each output pipeline
            for close_handler in self.close_handlers:
                close_handler()
            print(f'Pipeline {self.name} finished.')

# %%
class Pipeline(threading.Thread):
    def __init__(self, name: str, pipeline: dict):
        super().__init__()
        self.name = name
        self.outputs = self.init_outputs(pipeline['output'])
        self.input = self.init_input(pipeline['input'])

    def init_outputs(self, outputs_dict: dict):
        outputs={}
        for name, output in outputs_dict.items(): # name is arbitrary and doesn't matter
            output_type = output['type']
            assert output_type in file_type_to_extension.keys(), f'pipeline {self.name} output\'s file type {output_type} is not supported'
            if output_type == 'directory':
                outputs[name] = ImgDirOutput(name, output)
            elif output_type == 'rosbag':
                outputs[name] = RosbagOutput(name, output)
        return outputs

    def init_input(self, input_dict: dict):
        assert input_dict['type'] in file_type_to_extension.keys(), f'pipeline {self.name} input\'s file type {input_dict["type"]} is not supported'
        if input_dict['type'] == 'mp4':
            return MP4Input(self.name, input_dict, self.outputs)

    def run(self):
        print(f"{self.name} pipeline started.")
        self.input.loop()

# %%
def verify_file(path: str, type: str) -> bool:
    # verify the file/directory exists
    assert os.path.exists(path), f'file {path} does not exist'

    # verify the file type is supported
    assert type in file_type_to_extension.keys(), f'file type {type} is not supported'

    # verify the file type matches the extension or the path is a directory
    if type == "directory":
        assert os.path.isdir(path), f'{path} is not a directory'
    else:
        assert os.path.splitext(path)[-1] == file_type_to_extension[type], f'file {path} is not a {type} file'

    return True


def trace_config(cfg: dict):
    pipelines = []
    # verify that the config file contains "pipelines"
    assert "pipelines" in cfg and cfg["pipelines"], "pipeline is not specified in config file"

    print('Loaded config:')
    print("pipelines: ", end="")
    print(cfg["pipelines"], end="\n\n")

    for pipeline_name in cfg["pipelines"]:
        # verify that the pipeline is specified in the config file
        assert pipeline_name in cfg, f'pipeline {pipeline_name} is not specified in config file'

        pipeline = cfg[pipeline_name]

        # make directories for output and verify type
        for index, output in pipeline["output"].items():
            # verify the file type is supported
            assert output["type"] in file_type_to_extension.keys(), f'pipeline {pipeline_name}\'s output {index}\'s file type {output["type"]} is not supported'

            # make parent directories if they don't exist
            output["directory"] = os.path.dirname(output["path"]) if (output["type"] == "directory") else os.path.dirname(output["path"])
            os.makedirs(output["directory"], exist_ok=True)

        # verify input
        assert verify_file(path = pipeline["input"]["path"], type = pipeline["input"]["type"]), f'pipeline {pipeline_name}\'s input file {pipeline["input"]["path"]} is not valid'

        print(pipeline_name + ":")
        print_dict(pipeline, indent=1)

        pipelines.append(Pipeline(pipeline_name, pipeline))

    return pipelines

# %%
cfg_path="./config/wildfire/subcanopy/mp4_to_imgdir_rosbag.yaml"

cfg = load_config(cfg_path)

# %%
pipelines = trace_config(cfg)

for pipeline in pipelines:
    pipeline.start()
for pipeline in pipelines:
    pipeline.join()

print("All pipelines finished successfully.")
# Out:
# Loaded config:
# pipelines: ['camera_0', 'camera_1', 'camera_2', 'camera_3']
#
# camera_0:
#   input:
#     path: /root/data/wildfire/subcanopy/2023-04-27_FIRE-SGL-228/1/camera_0_1677761985_629121776.mp4
#     type: mp4
#     width: 612
#     height: 514
#   output:
#     2:
#       path: /root/data/wildfire/subcanopy/2023-04-27_FIRE-SGL-228/1/camera_0.bag
#       type: rosbag
#       topic: /camera_0
#       frame_id: camera_0/optical_frame
#       directory: /root/data/wildfire/subcanopy/2023-04-27_FIRE-SGL-228/1
# camera_0 MP4Input's gstreamer pipeline string: filesrc location=/root/data/wildfire/subcanopy/2023-04-27_FIRE-SGL-228/1/camera_0_1677761985_629121776.mp4 ! decodebin ! nvvideoconvert ! video/x-raw,format=RGB,width=612,height=514 ! progressreport update-freq=1 name=camera_0_progress ! fakesink name=camera_0
# camera_1:
#   input:
#     path: /root/data/wildfire/subcanopy/2023-04-27_FIRE-SGL-228/1/camera_1_1677761985_962133776.mp4
#     type: mp4
#     width: 612
#     height: 514
#   output:
#     2:
#       path: /root/data/wildfire/subcanopy/2023-04-27_FIRE-SGL-228/1/camera_1.bag
#       type: rosbag
#       topic: /camera_1
#       frame_id: camera_1/optical_frame
#       directory: /root/data/wildfire/subcanopy/2023-04-27_FIRE-SGL-228/1
# camera_1 MP4Input's gstreamer pipeline string: filesrc location=/root/data/wildfire/subcanopy/2023-04-27_FIRE-SGL-228/1/camera_1_1677761985_962133776.mp4 ! decodebin ! nvvideoconvert ! video/x-raw,format=RGB,width=612,height=514 ! progressreport update-freq=1 name=camera_1_progress ! fakesink name=camera_1
# camera_2:
#   input:
#     path: /root/data/wildfire/subcanopy/2023-04-27_FIRE-SGL-228/1/camera_2_1677761986_311796776.mp4
#     type: mp4
#     width: 612
#     height: 514
#   output:
#     2:
#       path: /root/data/wildfire/subcanopy/2023-04-27_FIRE-SGL-228/1/camera_2.bag
#       type: rosbag
#       topic: /camera_2
#       frame_id: camera_2/optical_frame
#       directory: /root/data/wildfire/subcanopy/2023-04-27_FIRE-SGL-228/1
# camera_2 MP4Input's gstreamer pipeline string: filesrc location=/root/data/wildfire/subcanopy/2023-04-27_FIRE-SGL-228/1/camera_2_1677761986_311796776.mp4 ! decodebin ! nvvideoconvert ! video/x-raw,format=RGB,width=612,height=514 ! progressreport update-freq=1 name=camera_2_progress ! fakesink name=camera_2
# camera_3:
#   input:
#     path: /root/data/wildfire/subcanopy/2023-04-27_FIRE-SGL-228/1/camera_3_1677761986_644808776.mp4
#     type: mp4
#     width: 612
#     height: 514
#   output:
#     2:
#       path: /root/data/wildfire/subcanopy/2023-04-27_FIRE-SGL-228/1/camera_3.bag
#       type: rosbag
#       topic: /camera_3
#       frame_id: camera_3/optical_frame
#       directory: /root/data/wildfire/subcanopy/2023-04-27_FIRE-SGL-228/1
# camera_3 MP4Input's gstreamer pipeline string: filesrc location=/root/data/wildfire/subcanopy/2023-04-27_FIRE-SGL-228/1/camera_3_1677761986_644808776.mp4 ! decodebin ! nvvideoconvert ! video/x-raw,format=RGB,width=612,height=514 ! progressreport update-freq=1 name=camera_3_progress ! fakesink name=camera_3
# camera_0 pipeline started.
# camera_1 pipeline started.
# camera_2 pipeline started.
# camera_3 pipeline started.
# camera_0_progress (00:00:01): 2 / 919 seconds ( 0.2 %)
# camera_3_progress (00:00:01): 1 / 918 seconds ( 0.1 %)
# camera_1_progress (00:00:01): 2 / 918 seconds ( 0.2 %)
# camera_2_progress (00:00:01): 2 / 918 seconds ( 0.2 %)
# camera_0_progress (00:00:02): 6 / 919 seconds ( 0.7 %)
# camera_3_progress (00:00:02): 5 / 918 seconds ( 0.5 %)
# camera_1_progress (00:00:02): 6 / 918 seconds ( 0.7 %)
# camera_2_progress (00:00:02): 6 / 918 seconds ( 0.7 %)
# camera_2_progress (00:00:03): 9 / 918 seconds ( 1.0 %)
# camera_0_progress (00:00:03): 10 / 919 seconds ( 1.1 %)
# camera_3_progress (00:00:03): 9 / 918 seconds ( 1.0 %)
# camera_1_progress (00:00:03): 10 / 918 seconds ( 1.1 %)
# camera_2_progress (00:00:04): 13 / 918 seconds ( 1.4 %)
# camera_0_progress (00:00:04): 13 / 919 seconds ( 1.4 %)
# camera_3_progress (00:00:04): 12 / 918 seconds ( 1.3 %)
# camera_1_progress (00:00:04): 13 / 918 seconds ( 1.4 %)
# camera_1_progress (00:00:05): 16 / 918 seconds ( 1.7 %)
# camera_2_progress (00:00:05): 16 / 918 seconds ( 1.7 %)
# camera_0_progress (00:00:05): 16 / 919 seconds ( 1.7 %)
# camera_3_progress (00:00:05): 15 / 918 seconds ( 1.6 %)
# camera_3_progress (00:00:06): 19 / 918 seconds ( 2.1 %)
# camera_1_progress (00:00:06): 19 / 918 seconds ( 2.1 %)
# camera_2_progress (00:00:06): 19 / 918 seconds ( 2.1 %)
# camera_0_progress (00:00:06): 20 / 919 seconds ( 2.2 %)
# camera_2_progress (00:00:07): 22 / 918 seconds ( 2.4 %)
# camera_0_progress (00:00:07): 23 / 919 seconds ( 2.5 %)
# camera_3_progress (00:00:07): 22 / 918 seconds ( 2.4 %)
# camera_1_progress (00:00:07): 23 / 918 seconds ( 2.5 %)
# camera_2_progress (00:00:08): 26 / 918 seconds ( 2.8 %)
# camera_3_progress (00:00:08): 26 / 918 seconds ( 2.8 %)
# camera_1_progress (00:00:08): 26 / 918 seconds ( 2.8 %)
# camera_0_progress (00:00:08): 27 / 919 seconds ( 2.9 %)
# camera_3_progress (00:00:09): 29 / 918 seconds ( 3.2 %)
# camera_1_progress (00:00:09): 29 / 918 seconds ( 3.2 %)
# camera_2_progress (00:00:09): 29 / 918 seconds ( 3.2 %)
# camera_0_progress (00:00:09): 30 / 919 seconds ( 3.3 %)
# camera_3_progress (00:00:10): 32 / 918 seconds ( 3.5 %)
# camera_1_progress (00:00:10): 33 / 918 seconds ( 3.6 %)
# camera_2_progress (00:00:10): 33 / 918 seconds ( 3.6 %)
# camera_0_progress (00:00:10): 33 / 919 seconds ( 3.6 %)
# camera_0_progress (00:00:11): 36 / 919 seconds ( 3.9 %)
# camera_3_progress (00:00:11): 35 / 918 seconds ( 3.8 %)
# camera_1_progress (00:00:11): 36 / 918 seconds ( 3.9 %)
# camera_2_progress (00:00:11): 36 / 918 seconds ( 3.9 %)
# camera_0_progress (00:00:12): 40 / 919 seconds ( 4.4 %)
# camera_3_progress (00:00:12): 39 / 918 seconds ( 4.2 %)
# camera_1_progress (00:00:12): 39 / 918 seconds ( 4.2 %)
# camera_2_progress (00:00:12): 39 / 918 seconds ( 4.2 %)
# camera_3_progress (00:00:13): 42 / 918 seconds ( 4.6 %)
# camera_1_progress (00:00:13): 42 / 918 seconds ( 4.6 %)
# camera_2_progress (00:00:13): 42 / 918 seconds ( 4.6 %)
# camera_0_progress (00:00:13): 43 / 919 seconds ( 4.7 %)
# camera_3_progress (00:00:14): 45 / 918 seconds ( 4.9 %)
# camera_1_progress (00:00:14): 46 / 918 seconds ( 5.0 %)
# camera_2_progress (00:00:14): 45 / 918 seconds ( 4.9 %)
# camera_0_progress (00:00:14): 46 / 919 seconds ( 5.0 %)
# camera_3_progress (00:00:15): 48 / 918 seconds ( 5.2 %)
# camera_1_progress (00:00:15): 49 / 918 seconds ( 5.3 %)
# camera_2_progress (00:00:15): 49 / 918 seconds ( 5.3 %)
# camera_0_progress (00:00:15): 50 / 919 seconds ( 5.4 %)
# camera_2_progress (00:00:16): 52 / 918 seconds ( 5.7 %)
# camera_0_progress (00:00:16): 52 / 919 seconds ( 5.7 %)
# camera_3_progress (00:00:16): 51 / 918 seconds ( 5.6 %)
# camera_1_progress (00:00:16): 52 / 918 seconds ( 5.7 %)
# camera_0_progress (00:00:17): 55 / 919 seconds ( 6.0 %)
# camera_3_progress (00:00:17): 54 / 918 seconds ( 5.9 %)
# camera_1_progress (00:00:17): 54 / 918 seconds ( 5.9 %)
# camera_2_progress (00:00:17): 54 / 918 seconds ( 5.9 %)
# camera_3_progress (00:00:18): 56 / 918 seconds ( 6.1 %)
# camera_1_progress (00:00:18): 57 / 918 seconds ( 6.2 %)
# camera_2_progress (00:00:18): 57 / 918 seconds ( 6.2 %)
# camera_0_progress (00:00:18): 57 / 919 seconds ( 6.2 %)
# camera_2_progress (00:00:19): 59 / 918 seconds ( 6.4 %)
# camera_3_progress (00:00:19): 59 / 918 seconds ( 6.4 %)
# camera_1_progress (00:00:19): 60 / 918 seconds ( 6.5 %)
# camera_0_progress (00:00:19): 60 / 919 seconds ( 6.5 %)
# camera_2_progress (00:00:20): 62 / 918 seconds ( 6.8 %)
# camera_0_progress (00:00:20): 62 / 919 seconds ( 6.7 %)
# camera_3_progress (00:00:20): 61 / 918 seconds ( 6.6 %)
# camera_1_progress (00:00:20): 62 / 918 seconds ( 6.8 %)
# camera_0_progress (00:00:21): 65 / 919 seconds ( 7.1 %)
# camera_3_progress (00:00:21): 64 / 918 seconds ( 7.0 %)
# camera_1_progress (00:00:21): 64 / 918 seconds ( 7.0 %)
# camera_2_progress (00:00:21): 64 / 918 seconds ( 7.0 %)
# camera_0_progress (00:00:22): 68 / 919 seconds ( 7.4 %)
# camera_3_progress (00:00:22): 67 / 918 seconds ( 7.3 %)
# camera_1_progress (00:00:22): 67 / 918 seconds ( 7.3 %)
# camera_2_progress (00:00:22): 67 / 918 seconds ( 7.3 %)
# camera_2_progress (00:00:23): 69 / 918 seconds ( 7.5 %)
# camera_0_progress (00:00:23): 70 / 919 seconds ( 7.6 %)
# camera_3_progress (00:00:23): 69 / 918 seconds ( 7.5 %)
# camera_1_progress (00:00:23): 70 / 918 seconds ( 7.6 %)
# camera_2_progress (00:00:24): 72 / 918 seconds ( 7.8 %)
# camera_0_progress (00:00:24): 72 / 919 seconds ( 7.8 %)
# camera_3_progress (00:00:24): 72 / 918 seconds ( 7.8 %)
# camera_1_progress (00:00:24): 72 / 918 seconds ( 7.8 %)
# camera_3_progress (00:00:25): 74 / 918 seconds ( 8.1 %)
# camera_1_progress (00:00:25): 75 / 918 seconds ( 8.2 %)
# camera_2_progress (00:00:25): 74 / 918 seconds ( 8.1 %)
# camera_0_progress (00:00:25): 75 / 919 seconds ( 8.2 %)
# camera_3_progress (00:00:26): 77 / 918 seconds ( 8.4 %)
# camera_1_progress (00:00:26): 77 / 918 seconds ( 8.4 %)
# camera_2_progress (00:00:26): 77 / 918 seconds ( 8.4 %)
# camera_0_progress (00:00:26): 78 / 919 seconds ( 8.5 %)
# camera_3_progress (00:00:27): 79 / 918 seconds ( 8.6 %)
# camera_1_progress (00:00:27): 80 / 918 seconds ( 8.7 %)
# camera_2_progress (00:00:27): 80 / 918 seconds ( 8.7 %)
# camera_0_progress (00:00:27): 80 / 919 seconds ( 8.7 %)
# camera_2_progress (00:00:28): 82 / 918 seconds ( 8.9 %)
# camera_0_progress (00:00:28): 83 / 919 seconds ( 9.0 %)
# camera_3_progress (00:00:28): 82 / 918 seconds ( 8.9 %)
# camera_1_progress (00:00:28): 83 / 918 seconds ( 9.0 %)
# camera_0_progress (00:00:29): 86 / 919 seconds ( 9.4 %)
# camera_3_progress (00:00:29): 85 / 918 seconds ( 9.3 %)
# camera_1_progress (00:00:29): 85 / 918 seconds ( 9.3 %)
# camera_2_progress (00:00:29): 85 / 918 seconds ( 9.3 %)
# camera_0_progress (00:00:30): 88 / 919 seconds ( 9.6 %)
# camera_3_progress (00:00:30): 87 / 918 seconds ( 9.5 %)
# camera_1_progress (00:00:30): 88 / 918 seconds ( 9.6 %)
# camera_2_progress (00:00:30): 88 / 918 seconds ( 9.6 %)
# camera_0_progress (00:00:31): 91 / 919 seconds ( 9.9 %)
# camera_3_progress (00:00:31): 90 / 918 seconds ( 9.8 %)
# camera_1_progress (00:00:31): 90 / 918 seconds ( 9.8 %)
# camera_2_progress (00:00:31): 90 / 918 seconds ( 9.8 %)
# camera_2_progress (00:00:32): 93 / 918 seconds (10.1 %)
# camera_0_progress (00:00:32): 93 / 919 seconds (10.1 %)
# camera_3_progress (00:00:32): 92 / 918 seconds (10.0 %)
# camera_1_progress (00:00:32): 93 / 918 seconds (10.1 %)
# camera_0_progress (00:00:33): 96 / 919 seconds (10.4 %)
# camera_3_progress (00:00:33): 95 / 918 seconds (10.3 %)
# camera_1_progress (00:00:33): 96 / 918 seconds (10.5 %)
# camera_2_progress (00:00:33): 95 / 918 seconds (10.3 %)
# camera_0_progress (00:00:34): 98 / 919 seconds (10.7 %)
# camera_3_progress (00:00:34): 97 / 918 seconds (10.6 %)
# camera_1_progress (00:00:34): 98 / 918 seconds (10.7 %)
# camera_2_progress (00:00:34): 98 / 918 seconds (10.7 %)
# camera_1_progress (00:00:35): 101 / 918 seconds (11.0 %)
# camera_2_progress (00:00:35): 100 / 918 seconds (10.9 %)
# camera_0_progress (00:00:35): 101 / 919 seconds (11.0 %)
# camera_3_progress (00:00:35): 100 / 918 seconds (10.9 %)
# camera_1_progress (00:00:36): 103 / 918 seconds (11.2 %)
# camera_2_progress (00:00:36): 103 / 918 seconds (11.2 %)
# camera_0_progress (00:00:36): 104 / 919 seconds (11.3 %)
# camera_3_progress (00:00:36): 103 / 918 seconds (11.2 %)
# camera_3_progress (00:00:37): 106 / 918 seconds (11.5 %)
# camera_1_progress (00:00:37): 106 / 918 seconds (11.5 %)
# camera_2_progress (00:00:37): 106 / 918 seconds (11.5 %)
# camera_0_progress (00:00:37): 107 / 919 seconds (11.6 %)
# camera_1_progress (00:00:38): 109 / 918 seconds (11.9 %)
# camera_2_progress (00:00:38): 109 / 918 seconds (11.9 %)
# camera_0_progress (00:00:38): 109 / 919 seconds (11.9 %)
# camera_3_progress (00:00:38): 108 / 918 seconds (11.8 %)
# camera_2_progress (00:00:39): 112 / 918 seconds (12.2 %)
# camera_0_progress (00:00:39): 112 / 919 seconds (12.2 %)
# camera_3_progress (00:00:39): 111 / 918 seconds (12.1 %)
# camera_1_progress (00:00:39): 112 / 918 seconds (12.2 %)
# camera_2_progress (00:00:40): 114 / 918 seconds (12.4 %)
# camera_0_progress (00:00:40): 115 / 919 seconds (12.5 %)
# camera_3_progress (00:00:40): 114 / 918 seconds (12.4 %)
# camera_1_progress (00:00:40): 115 / 918 seconds (12.5 %)
# camera_3_progress (00:00:41): 116 / 918 seconds (12.6 %)
# camera_1_progress (00:00:41): 117 / 918 seconds (12.7 %)
# camera_2_progress (00:00:41): 117 / 918 seconds (12.7 %)
# camera_0_progress (00:00:41): 117 / 919 seconds (12.7 %)
# camera_3_progress (00:00:42): 119 / 918 seconds (13.0 %)
# camera_1_progress (00:00:42): 120 / 918 seconds (13.1 %)
# camera_2_progress (00:00:42): 120 / 918 seconds (13.1 %)
# camera_0_progress (00:00:42): 120 / 919 seconds (13.1 %)
# camera_3_progress (00:00:43): 122 / 918 seconds (13.3 %)
# camera_1_progress (00:00:43): 123 / 918 seconds (13.4 %)
# camera_2_progress (00:00:43): 122 / 918 seconds (13.3 %)
# camera_0_progress (00:00:43): 123 / 919 seconds (13.4 %)
# camera_3_progress (00:00:44): 125 / 918 seconds (13.6 %)
# camera_1_progress (00:00:44): 126 / 918 seconds (13.7 %)
# camera_2_progress (00:00:44): 125 / 918 seconds (13.6 %)
# camera_0_progress (00:00:44): 126 / 919 seconds (13.7 %)
# camera_3_progress (00:00:45): 127 / 918 seconds (13.8 %)
# camera_1_progress (00:00:45): 128 / 918 seconds (13.9 %)
# camera_2_progress (00:00:45): 128 / 918 seconds (13.9 %)
# camera_0_progress (00:00:45): 128 / 919 seconds (13.9 %)
# camera_0_progress (00:00:46): 131 / 919 seconds (14.3 %)
# camera_3_progress (00:00:46): 130 / 918 seconds (14.2 %)
# camera_1_progress (00:00:46): 131 / 918 seconds (14.3 %)
# camera_2_progress (00:00:46): 130 / 918 seconds (14.2 %)
# camera_0_progress (00:00:47): 134 / 919 seconds (14.6 %)
# camera_3_progress (00:00:47): 133 / 918 seconds (14.5 %)
# camera_1_progress (00:00:47): 133 / 918 seconds (14.5 %)
# camera_2_progress (00:00:47): 133 / 918 seconds (14.5 %)
# camera_2_progress (00:00:48): 136 / 918 seconds (14.8 %)
# camera_0_progress (00:00:48): 137 / 919 seconds (14.9 %)
# camera_3_progress (00:00:48): 136 / 918 seconds (14.8 %)
# camera_1_progress (00:00:48): 136 / 918 seconds (14.8 %)
# camera_0_progress (00:00:49): 139 / 919 seconds (15.1 %)
# camera_3_progress (00:00:49): 138 / 918 seconds (15.0 %)
# camera_1_progress (00:00:49): 139 / 918 seconds (15.1 %)
# camera_2_progress (00:00:49): 139 / 918 seconds (15.1 %)
# camera_3_progress (00:00:50): 141 / 918 seconds (15.4 %)
# camera_1_progress (00:00:50): 142 / 918 seconds (15.5 %)
# camera_2_progress (00:00:50): 142 / 918 seconds (15.5 %)
# camera_0_progress (00:00:50): 142 / 919 seconds (15.5 %)
# camera_2_progress (00:00:51): 144 / 918 seconds (15.7 %)
# camera_3_progress (00:00:51): 144 / 918 seconds (15.7 %)
# camera_1_progress (00:00:51): 145 / 918 seconds (15.8 %)
# camera_0_progress (00:00:51): 145 / 919 seconds (15.8 %)
# camera_1_progress (00:00:52): 147 / 918 seconds (16.0 %)
# camera_2_progress (00:00:52): 147 / 918 seconds (16.0 %)
# camera_0_progress (00:00:52): 147 / 919 seconds (16.0 %)
# camera_3_progress (00:00:52): 146 / 918 seconds (15.9 %)
# camera_2_progress (00:00:53): 150 / 918 seconds (16.3 %)
# camera_0_progress (00:00:53): 150 / 919 seconds (16.3 %)
# camera_3_progress (00:00:53): 149 / 918 seconds (16.2 %)
# camera_1_progress (00:00:53): 150 / 918 seconds (16.3 %)
# camera_0_progress (00:00:54): 153 / 919 seconds (16.6 %)
# camera_3_progress (00:00:54): 152 / 918 seconds (16.6 %)
# camera_1_progress (00:00:54): 153 / 918 seconds (16.7 %)
# camera_2_progress (00:00:54): 153 / 918 seconds (16.7 %)
# camera_0_progress (00:00:55): 156 / 919 seconds (17.0 %)
# camera_3_progress (00:00:55): 155 / 918 seconds (16.9 %)
# camera_1_progress (00:00:55): 156 / 918 seconds (17.0 %)
# camera_2_progress (00:00:55): 155 / 918 seconds (16.9 %)
# camera_1_progress (00:00:56): 158 / 918 seconds (17.2 %)
# camera_2_progress (00:00:56): 158 / 918 seconds (17.2 %)
# camera_0_progress (00:00:56): 159 / 919 seconds (17.3 %)
# camera_3_progress (00:00:56): 158 / 918 seconds (17.2 %)
# camera_0_progress (00:00:57): 161 / 919 seconds (17.5 %)
# camera_3_progress (00:00:57): 160 / 918 seconds (17.4 %)
# camera_1_progress (00:00:57): 161 / 918 seconds (17.5 %)
# camera_2_progress (00:00:57): 161 / 918 seconds (17.5 %)
# camera_2_progress (00:00:58): 163 / 918 seconds (17.8 %)
# camera_3_progress (00:00:58): 163 / 918 seconds (17.8 %)
# camera_1_progress (00:00:58): 164 / 918 seconds (17.9 %)
# camera_0_progress (00:00:58): 164 / 919 seconds (17.8 %)
# camera_3_progress (00:00:59): 166 / 918 seconds (18.1 %)
# camera_1_progress (00:00:59): 166 / 918 seconds (18.1 %)
# camera_2_progress (00:00:59): 166 / 918 seconds (18.1 %)
# camera_0_progress (00:00:59): 167 / 919 seconds (18.2 %)
# camera_3_progress (00:01:00): 168 / 918 seconds (18.3 %)
# camera_1_progress (00:01:00): 169 / 918 seconds (18.4 %)
# camera_2_progress (00:01:00): 169 / 918 seconds (18.4 %)
# camera_0_progress (00:01:00): 169 / 919 seconds (18.4 %)
# camera_1_progress (00:01:01): 172 / 918 seconds (18.7 %)
# camera_3_progress (00:01:12): 201 / 918 seconds (21.9 %)
# camera_0_progress (00:01:13): 204 / 919 seconds (22.2 %)
# camera_3_progress (00:01:13): 203 / 918 seconds (22.1 %)
# camera_1_progress (00:01:13): 204 / 918 seconds (22.2 %)
# camera_2_progress (00:01:13): 204 / 918 seconds (22.2 %)
# camera_0_progress (00:01:14): 207 / 919 seconds (22.5 %)
# camera_3_progress (00:01:14): 206 / 918 seconds (22.4 %)
# camera_1_progress (00:01:14): 207 / 918 seconds (22.5 %)
# camera_2_progress (00:01:14): 207 / 918 seconds (22.5 %)
# camera_3_progress (00:01:15): 209 / 918 seconds (22.8 %)
# camera_1_progress (00:01:15): 210 / 918 seconds (22.9 %)
# camera_2_progress (00:01:15): 209 / 918 seconds (22.8 %)
# camera_0_progress (00:01:15): 210 / 919 seconds (22.9 %)
# camera_2_progress (00:01:16): 212 / 918 seconds (23.1 %)
# camera_0_progress (00:01:16): 213 / 919 seconds (23.2 %)
# camera_3_progress (00:01:16): 212 / 918 seconds (23.1 %)
# camera_1_progress (00:01:16): 212 / 918 seconds (23.1 %)
# camera_1_progress (00:01:17): 215 / 918 seconds (23.4 %)
# camera_2_progress (00:01:17): 215 / 918 seconds (23.4 %)
# camera_0_progress (00:01:17): 215 / 919 seconds (23.4 %)
# camera_3_progress (00:01:17): 214 / 918 seconds (23.3 %)
# camera_2_progress (00:01:18): 217 / 918 seconds (23.6 %)
# camera_0_progress (00:01:18): 218 / 919 seconds (23.7 %)
# camera_3_progress (00:01:18): 217 / 918 seconds (23.6 %)
# camera_1_progress (00:01:18): 217 / 918 seconds (23.6 %)
# camera_2_progress (00:01:19): 220 / 918 seconds (24.0 %)
# camera_0_progress (00:01:19): 220 / 919 seconds (23.9 %)
# camera_3_progress (00:01:19): 219 / 918 seconds (23.9 %)
# camera_1_progress (00:01:19): 220 / 918 seconds (24.0 %)
# camera_0_progress (00:01:20): 223 / 919 seconds (24.3 %)
# camera_3_progress (00:01:20): 222 / 918 seconds (24.2 %)
# camera_1_progress (00:01:20): 222 / 918 seconds (24.2 %)
# camera_2_progress (00:01:20): 222 / 918 seconds (24.2 %)
# camera_2_progress (00:01:21): 225 / 918 seconds (24.5 %)
# camera_0_progress (00:01:21): 225 / 919 seconds (24.5 %)
# camera_3_progress (00:01:21): 225 / 918 seconds (24.5 %)
# camera_1_progress (00:01:21): 225 / 918 seconds (24.5 %)
# camera_1_progress (00:01:22): 228 / 918 seconds (24.8 %)
# camera_2_progress (00:01:22): 228 / 918 seconds (24.8 %)
# camera_0_progress (00:01:22): 228 / 919 seconds (24.8 %)
# camera_3_progress (00:01:22): 227 / 918 seconds (24.7 %)
# camera_0_progress (00:01:23): 231 / 919 seconds (25.1 %)
# camera_3_progress (00:01:23): 230 / 918 seconds (25.1 %)
# camera_1_progress (00:01:23): 230 / 918 seconds (25.1 %)
# camera_2_progress (00:01:23): 230 / 918 seconds (25.1 %)
# camera_0_progress (00:01:24): 233 / 919 seconds (25.4 %)
# camera_3_progress (00:01:47): 292 / 918 seconds (31.8 %)
# camera_1_progress (00:01:47): 292 / 918 seconds (31.8 %)
# camera_2_progress (00:01:47): 292 / 918 seconds (31.8 %)
# camera_2_progress (00:01:48): 295 / 918 seconds (32.1 %)
# camera_0_progress (00:01:48): 295 / 919 seconds (32.1 %)
# camera_3_progress (00:01:48): 294 / 918 seconds (32.0 %)
# camera_1_progress (00:01:48): 295 / 918 seconds (32.1 %)
# camera_0_progress (00:01:49): 298 / 919 seconds (32.4 %)
# camera_3_progress (00:01:49): 297 / 918 seconds (32.4 %)
# camera_1_progress (00:01:49): 298 / 918 seconds (32.5 %)
# camera_2_progress (00:01:49): 297 / 918 seconds (32.4 %)
# camera_0_progress (00:01:50): 300 / 919 seconds (32.6 %)
# camera_3_progress (00:01:50): 300 / 918 seconds (32.7 %)
# camera_1_progress (00:01:50): 300 / 918 seconds (32.7 %)
# camera_2_progress (00:01:50): 300 / 918 seconds (32.7 %)
# camera_3_progress (00:01:51): 302 / 918 seconds (32.9 %)
# camera_1_progress (00:01:51): 303 / 918 seconds (33.0 %)
# camera_2_progress (00:01:51): 302 / 918 seconds (32.9 %)
# camera_0_progress (00:01:51): 303 / 919 seconds (33.0 %)
# camera_1_progress (00:01:52): 305 / 918 seconds (33.2 %)
# camera_2_progress (00:01:52): 305 / 918 seconds (33.2 %)
# camera_0_progress (00:01:52): 305 / 919 seconds (33.2 %)
# camera_3_progress (00:01:52): 305 / 918 seconds (33.2 %)
# camera_3_progress (00:01:53): 307 / 918 seconds (33.4 %)
# camera_1_progress (00:01:53): 308 / 918 seconds (33.6 %)
# camera_2_progress (00:01:53): 307 / 918 seconds (33.4 %)
# camera_0_progress (00:01:53): 308 / 919 seconds (33.5 %)
# camera_2_progress (00:01:54): 310 / 918 seconds (33.8 %)
# camera_0_progress (00:01:54): 311 / 919 seconds (33.8 %)
# camera_3_progress (00:01:54): 310 / 918 seconds (33.8 %)
# camera_1_progress (00:01:54): 310 / 918 seconds (33.8 %)
# camera_3_progress (00:01:55): 312 / 918 seconds (34.0 %)
# camera_1_progress (00:01:55): 313 / 918 seconds (34.1 %)
# camera_2_progress (00:01:55): 313 / 918 seconds (34.1 %)
# camera_0_progress (00:01:55): 313 / 919 seconds (34.1 %)
# camera_1_progress (00:01:56): 316 / 918 seconds (34.4 %)
# camera_2_progress (00:01:56): 315 / 918 seconds (34.3 %)
# camera_0_progress (00:01:56): 316 / 919 seconds (34.4 %)
# camera_3_progress (00:01:56): 315 / 918 seconds (34.3 %)
# camera_2_progress (00:01:57): 318 / 918 seconds (34.6 %)
# camera_0_progress (00:01:57): 318 / 919 seconds (34.6 %)
# camera_3_progress (00:01:57): 317 / 918 seconds (34.5 %)
# camera_1_progress (00:01:57): 318 / 918 seconds (34.6 %)
# camera_1_progress (00:01:58): 320 / 918 seconds (34.9 %)
# camera_2_progress (00:01:58): 320 / 918 seconds (34.9 %)
# camera_0_progress (00:01:58): 321 / 919 seconds (34.9 %)
# camera_3_progress (00:01:58): 320 / 918 seconds (34.9 %)
# camera_2_progress (00:01:59): 323 / 918 seconds (35.2 %)
# camera_3_progress (00:01:59): 323 / 918 seconds (35.2 %)
# camera_1_progress (00:01:59): 323 / 918 seconds (35.2 %)
# camera_0_progress (00:01:59): 324 / 919 seconds (35.3 %)
# camera_0_progress (00:02:00): 326 / 919 seconds (35.5 %)
# camera_3_progress (00:02:00): 325 / 918 seconds (35.4 %)
# camera_1_progress (00:02:00): 326 / 918 seconds (35.5 %)
# camera_2_progress (00:02:00): 326 / 918 seconds (35.5 %)
# camera_1_progress (00:02:01): 328 / 918 seconds (35.7 %)
# camera_2_progress (00:02:01): 328 / 918 seconds (35.7 %)
# camera_0_progress (00:02:01): 329 / 919 seconds (35.8 %)
# camera_3_progress (00:02:01): 328 / 918 seconds (35.7 %)
# camera_1_progress (00:02:02): 331 / 918 seconds (36.1 %)
# camera_2_progress (00:02:02): 331 / 918 seconds (36.1 %)
# camera_0_progress (00:02:02): 331 / 919 seconds (36.0 %)
# camera_3_progress (00:02:02): 330 / 918 seconds (35.9 %)
# camera_3_progress (00:02:03): 333 / 918 seconds (36.3 %)
# camera_1_progress (00:02:03): 334 / 918 seconds (36.4 %)
# camera_2_progress (00:02:03): 333 / 918 seconds (36.3 %)
# camera_0_progress (00:02:03): 334 / 919 seconds (36.3 %)
# camera_0_progress (00:02:04): 336 / 919 seconds (36.6 %)
# camera_3_progress (00:02:04): 335 / 918 seconds (36.5 %)
# camera_1_progress (00:02:04): 336 / 918 seconds (36.6 %)
# camera_2_progress (00:02:04): 336 / 918 seconds (36.6 %)
# camera_0_progress (00:02:05): 339 / 919 seconds (36.9 %)
# camera_3_progress (00:02:05): 338 / 918 seconds (36.8 %)
# camera_1_progress (00:02:05): 339 / 918 seconds (36.9 %)
# camera_2_progress (00:02:05): 338 / 918 seconds (36.8 %)
# camera_1_progress (00:02:06): 341 / 918 seconds (37.1 %)
# camera_2_progress (00:02:06): 341 / 918 seconds (37.1 %)
# camera_0_progress (00:02:06): 342 / 919 seconds (37.2 %)
# camera_3_progress (00:02:06): 341 / 918 seconds (37.1 %)
# camera_0_progress (00:02:07): 344 / 919 seconds (37.4 %)
# camera_3_progress (00:02:07): 343 / 918 seconds (37.4 %)
# camera_1_progress (00:02:07): 344 / 918 seconds (37.5 %)
# camera_2_progress (00:02:07): 344 / 918 seconds (37.5 %)
# camera_1_progress (00:02:08): 347 / 918 seconds (37.8 %)
# camera_2_progress (00:02:08): 346 / 918 seconds (37.7 %)
# camera_0_progress (00:02:08): 347 / 919 seconds (37.8 %)
# camera_3_progress (00:02:08): 346 / 918 seconds (37.7 %)
# camera_3_progress (00:02:09): 349 / 918 seconds (38.0 %)
# camera_1_progress (00:02:09): 349 / 918 seconds (38.0 %)
# camera_2_progress (00:02:09): 349 / 918 seconds (38.0 %)
# camera_0_progress (00:02:09): 350 / 919 seconds (38.1 %)
# camera_2_progress (00:02:10): 351 / 918 seconds (38.2 %)
# camera_0_progress (00:02:10): 352 / 919 seconds (38.3 %)
# camera_3_progress (00:02:10): 351 / 918 seconds (38.2 %)
# camera_1_progress (00:02:10): 352 / 918 seconds (38.3 %)
# camera_3_progress (00:02:11): 354 / 918 seconds (38.6 %)
# camera_1_progress (00:02:11): 354 / 918 seconds (38.6 %)
# camera_2_progress (00:02:11): 354 / 918 seconds (38.6 %)
# camera_0_progress (00:02:11): 355 / 919 seconds (38.6 %)
# camera_3_progress (00:02:12): 356 / 918 seconds (38.8 %)
# camera_1_progress (00:02:12): 357 / 918 seconds (38.9 %)
# camera_2_progress (00:02:12): 357 / 918 seconds (38.9 %)
# camera_0_progress (00:02:12): 357 / 919 seconds (38.8 %)
# camera_2_progress (00:02:13): 359 / 918 seconds (39.1 %)
# camera_0_progress (00:02:13): 360 / 919 seconds (39.2 %)
# camera_3_progress (00:02:13): 359 / 918 seconds (39.1 %)
# camera_1_progress (00:02:13): 359 / 918 seconds (39.1 %)
# camera_0_progress (00:02:14): 362 / 919 seconds (39.4 %)
# camera_3_progress (00:02:14): 361 / 918 seconds (39.3 %)
# camera_1_progress (00:02:14): 362 / 918 seconds (39.4 %)
# camera_2_progress (00:02:14): 362 / 918 seconds (39.4 %)
# camera_2_progress (00:02:15): 364 / 918 seconds (39.7 %)
# camera_0_progress (00:02:15): 365 / 919 seconds (39.7 %)
# camera_3_progress (00:02:15): 364 / 918 seconds (39.7 %)
# camera_1_progress (00:02:15): 365 / 918 seconds (39.8 %)
# camera_3_progress (00:02:16): 366 / 918 seconds (39.9 %)
# camera_1_progress (00:02:16): 367 / 918 seconds (40.0 %)
# camera_2_progress (00:02:16): 367 / 918 seconds (40.0 %)
# camera_0_progress (00:02:16): 367 / 919 seconds (39.9 %)
# camera_2_progress (00:02:17): 370 / 918 seconds (40.3 %)
# camera_3_progress (00:02:17): 369 / 918 seconds (40.2 %)
# camera_1_progress (00:02:17): 370 / 918 seconds (40.3 %)
# camera_0_progress (00:02:17): 371 / 919 seconds (40.4 %)
# camera_0_progress (00:02:18): 372 / 919 seconds (40.5 %)
# camera_3_progress (00:02:18): 372 / 918 seconds (40.5 %)
# camera_1_progress (00:02:18): 372 / 918 seconds (40.5 %)
# camera_2_progress (00:02:18): 372 / 918 seconds (40.5 %)
# camera_3_progress (00:02:19): 374 / 918 seconds (40.7 %)
# camera_1_progress (00:02:19): 375 / 918 seconds (40.8 %)
# camera_2_progress (00:02:19): 374 / 918 seconds (40.7 %)
# camera_0_progress (00:02:19): 375 / 919 seconds (40.8 %)
# camera_2_progress (00:02:20): 377 / 918 seconds (41.1 %)
# camera_0_progress (00:02:20): 377 / 919 seconds (41.0 %)
# camera_3_progress (00:02:20): 376 / 918 seconds (41.0 %)
# camera_1_progress (00:02:20): 377 / 918 seconds (41.1 %)
# camera_0_progress (00:02:21): 380 / 919 seconds (41.3 %)
# camera_3_progress (00:02:21): 379 / 918 seconds (41.3 %)
# camera_1_progress (00:02:21): 380 / 918 seconds (41.4 %)
# camera_3_progress (00:02:56): 469 / 918 seconds (51.1 %)
# camera_1_progress (00:02:56): 470 / 918 seconds (51.2 %)
# camera_2_progress (00:02:56): 470 / 918 seconds (51.2 %)
# camera_2_progress (00:02:57): 472 / 918 seconds (51.4 %)
# camera_3_progress (00:02:57): 472 / 918 seconds (51.4 %)
# camera_1_progress (00:02:57): 473 / 918 seconds (51.5 %)
# camera_0_progress (00:02:57): 473 / 919 seconds (51.5 %)
# camera_2_progress (00:02:58): 475 / 918 seconds (51.7 %)
# camera_0_progress (00:02:58): 475 / 919 seconds (51.7 %)
# camera_3_progress (00:02:58): 474 / 918 seconds (51.6 %)
# camera_1_progress (00:02:58): 475 / 918 seconds (51.7 %)
# camera_0_progress (00:02:59): 478 / 919 seconds (52.0 %)
# camera_3_progress (00:02:59): 477 / 918 seconds (52.0 %)
# camera_1_progress (00:02:59): 478 / 918 seconds (52.1 %)
# camera_2_progress (00:02:59): 477 / 918 seconds (52.0 %)
# camera_1_progress (00:03:00): 480 / 918 seconds (52.3 %)
# camera_2_progress (00:03:00): 480 / 918 seconds (52.3 %)
# camera_0_progress (00:03:00): 480 / 919 seconds (52.2 %)
# camera_3_progress (00:03:00): 480 / 918 seconds (52.3 %)
# camera_2_progress (00:03:01): 483 / 918 seconds (52.6 %)
# camera_0_progress (00:03:01): 483 / 919 seconds (52.6 %)
# camera_3_progress (00:03:01): 482 / 918 seconds (52.5 %)
# camera_1_progress (00:03:01): 483 / 918 seconds (52.6 %)
# camera_3_progress (00:03:02): 485 / 918 seconds (52.8 %)
# camera_1_progress (00:03:02): 485 / 918 seconds (52.8 %)
# camera_2_progress (00:03:02): 485 / 918 seconds (52.8 %)
# camera_0_progress (00:03:02): 486 / 919 seconds (52.9 %)
# camera_3_progress (00:03:03): 487 / 918 seconds (53.1 %)
# camera_1_progress (00:03:03): 488 / 918 seconds (53.2 %)
# camera_2_progress (00:03:03): 487 / 918 seconds (53.1 %)
# camera_0_progress (00:03:03): 488 / 919 seconds (53.1 %)
# camera_3_progress (00:03:04): 489 / 918 seconds (53.3 %)
# camera_1_progress (00:03:04): 490 / 918 seconds (53.4 %)
# camera_2_progress (00:03:04): 490 / 918 seconds (53.4 %)
# camera_0_progress (00:03:04): 491 / 919 seconds (53.4 %)
# camera_0_progress (00:03:05): 493 / 919 seconds (53.6 %)
# camera_3_progress (00:03:05): 492 / 918 seconds (53.6 %)
# camera_1_progress (00:03:05): 493 / 918 seconds (53.7 %)
# camera_2_progress (00:03:05): 493 / 918 seconds (53.7 %)
# camera_0_progress (00:03:06): 496 / 919 seconds (54.0 %)
# camera_3_progress (00:03:06): 495 / 918 seconds (53.9 %)
# camera_1_progress (00:03:06): 495 / 918 seconds (53.9 %)
# camera_2_progress (00:03:06): 495 / 918 seconds (53.9 %)
# camera_2_progress (00:03:07): 498 / 918 seconds (54.2 %)
# camera_0_progress (00:03:07): 498 / 919 seconds (54.2 %)
# camera_3_progress (00:03:07): 497 / 918 seconds (54.1 %)
# camera_1_progress (00:03:07): 498 / 918 seconds (54.2 %)
# camera_0_progress (00:03:08): 501 / 919 seconds (54.5 %)
# camera_3_progress (00:03:08): 500 / 918 seconds (54.5 %)
# camera_1_progress (00:03:08): 500 / 918 seconds (54.5 %)
# camera_2_progress (00:03:08): 500 / 918 seconds (54.5 %)
# camera_0_progress (00:03:09): 503 / 919 seconds (54.7 %)
# camera_3_progress (00:03:09): 502 / 918 seconds (54.7 %)
# camera_1_progress (00:03:09): 503 / 918 seconds (54.8 %)
# camera_2_progress (00:03:09): 503 / 918 seconds (54.8 %)
# camera_1_progress (00:03:10): 505 / 918 seconds (55.0 %)
# camera_2_progress (00:03:10): 505 / 918 seconds (55.0 %)
# camera_0_progress (00:03:10): 506 / 919 seconds (55.1 %)
# camera_3_progress (00:03:10): 505 / 918 seconds (55.0 %)
# camera_3_progress (00:03:11): 507 / 918 seconds (55.2 %)
# camera_1_progress (00:03:11): 508 / 918 seconds (55.3 %)
# camera_2_progress (00:03:11): 508 / 918 seconds (55.3 %)
# camera_0_progress (00:03:11): 508 / 919 seconds (55.3 %)
# camera_1_progress (00:03:12): 511 / 918 seconds (55.7 %)
# camera_2_progress (00:03:12): 510 / 918 seconds (55.6 %)
# camera_0_progress (00:03:12): 511 / 919 seconds (55.6 %)
# camera_3_progress (00:03:12): 510 / 918 seconds (55.6 %)
# camera_2_progress (00:03:13): 513 / 918 seconds (55.9 %)
# camera_0_progress (00:03:13): 513 / 919 seconds (55.8 %)
# camera_3_progress (00:03:13): 512 / 918 seconds (55.8 %)
# camera_1_progress (00:03:13): 513 / 918 seconds (55.9 %)
# camera_0_progress (00:03:14): 516 / 919 seconds (56.1 %)
# camera_3_progress (00:03:14): 515 / 918 seconds (56.1 %)
# camera_1_progress (00:03:14): 516 / 918 seconds (56.2 %)
# camera_2_progress (00:03:14): 515 / 918 seconds (56.1 %)
# camera_0_progress (00:03:15): 518 / 919 seconds (56.4 %)
# camera_3_progress (00:03:15): 517 / 918 seconds (56.3 %)
# camera_1_progress (00:03:15): 518 / 918 seconds (56.4 %)
# camera_2_progress (00:03:15): 518 / 918 seconds (56.4 %)
# camera_0_progress (00:03:16): 521 / 919 seconds (56.7 %)
# camera_3_progress (00:03:16): 520 / 918 seconds (56.6 %)
# camera_1_progress (00:03:16): 521 / 918 seconds (56.8 %)
# camera_2_progress (00:03:16): 521 / 918 seconds (56.8 %)
# camera_2_progress (00:03:17): 523 / 918 seconds (57.0 %)
# camera_0_progress (00:03:17): 524 / 919 seconds (57.0 %)
# camera_3_progress (00:03:17): 523 / 918 seconds (57.0 %)
# camera_1_progress (00:03:17): 523 / 918 seconds (57.0 %)
# camera_1_progress (00:03:18): 526 / 918 seconds (57.3 %)
# camera_2_progress (00:03:18): 526 / 918 seconds (57.3 %)
# ...
# camera_3_progress (00:04:46): 743 / 918 seconds (80.9 %)
# camera_1_progress (00:04:46): 744 / 918 seconds (81.0 %)
# camera_0_progress (00:04:47): 747 / 919 seconds (81.3 %)
# camera_3_progress (00:04:47): 746 / 918 seconds (81.3 %)
# camera_1_progress (00:04:47): 746 / 918 seconds (81.3 %)
# camera_2_progress (00:04:47): 746 / 918 seconds (81.3 %)
# camera_1_progress (00:04:48): 749 / 918 seconds (81.6 %)
# camera_2_progress (00:04:48): 748 / 918 seconds (81.5 %)
# camera_0_progress (00:04:48): 749 / 919 seconds (81.5 %)
# camera_3_progress (00:04:48): 748 / 918 seconds (81.5 %)
# camera_1_progress (00:04:49): 751 / 918 seconds (81.8 %)
# camera_2_progress (00:04:49): 751 / 918 seconds (81.8 %)
# camera_0_progress (00:04:49): 751 / 919 seconds (81.7 %)
# camera_3_progress (00:04:49): 751 / 918 seconds (81.8 %)
# camera_1_progress (00:04:50): 753 / 918 seconds (82.0 %)
# camera_2_progress (00:04:50): 753 / 918 seconds (82.0 %)
# camera_0_progress (00:04:50): 754 / 919 seconds (82.0 %)
# camera_3_progress (00:04:50): 753 / 918 seconds (82.0 %)
# camera_1_progress (00:04:51): 756 / 918 seconds (82.4 %)
# camera_2_progress (00:04:51): 756 / 918 seconds (82.4 %)
# camera_0_progress (00:04:51): 756 / 919 seconds (82.3 %)
# camera_3_progress (00:04:51): 756 / 918 seconds (82.4 %)
# camera_0_progress (00:04:52): 759 / 919 seconds (82.6 %)
# camera_3_progress (00:04:52): 758 / 918 seconds (82.6 %)
# camera_1_progress (00:04:52): 759 / 918 seconds (82.7 %)
# camera_2_progress (00:04:52): 758 / 918 seconds (82.6 %)
# camera_3_progress (00:04:53): 760 / 918 seconds (82.8 %)
# camera_1_progress (00:04:53): 761 / 918 seconds (82.9 %)
# camera_2_progress (00:04:53): 761 / 918 seconds (82.9 %)
# camera_0_progress (00:04:53): 761 / 919 seconds (82.8 %)
# camera_0_progress (00:04:54): 764 / 919 seconds (83.1 %)
# camera_3_progress (00:04:54): 763 / 918 seconds (83.1 %)
# camera_1_progress (00:04:54): 764 / 918 seconds (83.2 %)
# camera_2_progress (00:04:54): 763 / 918 seconds (83.1 %)
# camera_2_progress (00:04:55): 766 / 918 seconds (83.4 %)
# camera_0_progress (00:04:55): 766 / 919 seconds (83.4 %)
# camera_3_progress (00:04:55): 765 / 918 seconds (83.3 %)
# camera_1_progress (00:04:55): 766 / 918 seconds (83.4 %)
# camera_1_progress (00:04:56): 769 / 918 seconds (83.8 %)
# camera_2_progress (00:04:56): 768 / 918 seconds (83.7 %)
# camera_0_progress (00:04:56): 769 / 919 seconds (83.7 %)
# camera_3_progress (00:04:56): 768 / 918 seconds (83.7 %)
# camera_3_progress (00:04:57): 770 / 918 seconds (83.9 %)
# camera_1_progress (00:04:57): 771 / 918 seconds (84.0 %)
# camera_2_progress (00:04:57): 771 / 918 seconds (84.0 %)
# camera_0_progress (00:04:57): 771 / 919 seconds (83.9 %)
# camera_3_progress (00:04:58): 773 / 918 seconds (84.2 %)
# camera_1_progress (00:04:58): 774 / 918 seconds (84.3 %)
# camera_2_progress (00:04:58): 773 / 918 seconds (84.2 %)
# camera_0_progress (00:04:58): 774 / 919 seconds (84.2 %)
# camera_0_progress (00:04:59): 777 / 919 seconds (84.5 %)
# camera_3_progress (00:04:59): 776 / 918 seconds (84.5 %)
# camera_1_progress (00:04:59): 776 / 918 seconds (84.5 %)
# camera_2_progress (00:04:59): 776 / 918 seconds (84.5 %)
# camera_2_progress (00:05:00): 779 / 918 seconds (84.9 %)
# camera_3_progress (00:05:00): 778 / 918 seconds (84.7 %)
# camera_1_progress (00:05:00): 779 / 918 seconds (84.9 %)
# camera_0_progress (00:05:00): 779 / 919 seconds (84.8 %)
# camera_1_progress (00:05:01): 781 / 918 seconds (85.1 %)
# camera_2_progress (00:05:01): 781 / 918 seconds (85.1 %)
# camera_0_progress (00:05:01): 782 / 919 seconds (85.1 %)
# camera_3_progress (00:05:01): 781 / 918 seconds (85.1 %)
# camera_2_progress (00:05:02): 784 / 918 seconds (85.4 %)
# camera_0_progress (00:05:02): 784 / 919 seconds (85.3 %)
# camera_3_progress (00:05:02): 783 / 918 seconds (85.3 %)
# camera_1_progress (00:05:02): 784 / 918 seconds (85.4 %)
# camera_2_progress (00:05:03): 786 / 918 seconds (85.6 %)
# camera_0_progress (00:05:03): 787 / 919 seconds (85.6 %)
# camera_3_progress (00:05:03): 786 / 918 seconds (85.6 %)
# camera_1_progress (00:05:03): 787 / 918 seconds (85.7 %)
# camera_1_progress (00:05:04): 789 / 918 seconds (85.9 %)
# camera_2_progress (00:05:04): 789 / 918 seconds (85.9 %)
# camera_0_progress (00:05:04): 789 / 919 seconds (85.9 %)
# camera_3_progress (00:05:04): 788 / 918 seconds (85.8 %)
# camera_3_progress (00:05:05): 791 / 918 seconds (86.2 %)
# camera_1_progress (00:05:05): 791 / 918 seconds (86.2 %)
# camera_2_progress (00:05:05): 791 / 918 seconds (86.2 %)
# camera_0_progress (00:05:05): 792 / 919 seconds (86.2 %)
# camera_3_progress (00:05:06): 793 / 918 seconds (86.4 %)
# camera_1_progress (00:05:06): 794 / 918 seconds (86.5 %)
# camera_2_progress (00:05:06): 794 / 918 seconds (86.5 %)
# camera_0_progress (00:05:06): 794 / 919 seconds (86.4 %)
# camera_2_progress (00:05:07): 797 / 918 seconds (86.8 %)
# camera_3_progress (00:05:07): 796 / 918 seconds (86.7 %)
# camera_1_progress (00:05:07): 797 / 918 seconds (86.8 %)
# camera_0_progress (00:05:07): 797 / 919 seconds (86.7 %)
# camera_1_progress (00:05:08): 799 / 918 seconds (87.0 %)
# camera_2_progress (00:05:08): 799 / 918 seconds (87.0 %)
# camera_0_progress (00:05:08): 800 / 919 seconds (87.1 %)
# camera_3_progress (00:05:08): 799 / 918 seconds (87.0 %)
# camera_0_progress (00:05:09): 802 / 919 seconds (87.3 %)
# camera_3_progress (00:05:09): 801 / 918 seconds (87.3 %)
# camera_1_progress (00:05:09): 802 / 918 seconds (87.4 %)
# camera_2_progress (00:05:09): 802 / 918 seconds (87.4 %)
# camera_2_progress (00:05:10): 804 / 918 seconds (87.6 %)
# camera_0_progress (00:05:10): 804 / 919 seconds (87.5 %)
# camera_3_progress (00:05:10): 803 / 918 seconds (87.5 %)
# camera_1_progress (00:05:10): 804 / 918 seconds (87.6 %)
# camera_2_progress (00:05:11): 806 / 918 seconds (87.8 %)
# camera_0_progress (00:05:11): 807 / 919 seconds (87.8 %)
# camera_3_progress (00:05:11): 806 / 918 seconds (87.8 %)
# camera_1_progress (00:05:11): 807 / 918 seconds (87.9 %)
# camera_3_progress (00:05:12): 808 / 918 seconds (88.0 %)
# camera_1_progress (00:05:12): 809 / 918 seconds (88.1 %)
# camera_2_progress (00:05:12): 809 / 918 seconds (88.1 %)
# camera_0_progress (00:05:12): 809 / 919 seconds (88.0 %)
# camera_1_progress (00:05:13): 812 / 918 seconds (88.5 %)
# camera_2_progress (00:05:13): 811 / 918 seconds (88.3 %)
# camera_0_progress (00:05:13): 812 / 919 seconds (88.4 %)
# camera_3_progress (00:05:13): 811 / 918 seconds (88.3 %)
# camera_2_progress (00:05:14): 814 / 918 seconds (88.7 %)
# camera_0_progress (00:05:14): 814 / 919 seconds (88.6 %)
# camera_3_progress (00:05:14): 813 / 918 seconds (88.6 %)
# camera_1_progress (00:05:14): 814 / 918 seconds (88.7 %)
# camera_3_progress (00:05:15): 816 / 918 seconds (88.9 %)
# camera_1_progress (00:05:15): 817 / 918 seconds (89.0 %)
# camera_2_progress (00:05:15): 816 / 918 seconds (88.9 %)
# camera_0_progress (00:05:15): 817 / 919 seconds (88.9 %)
# camera_1_progress (00:05:16): 819 / 918 seconds (89.2 %)
# camera_2_progress (00:05:16): 819 / 918 seconds (89.2 %)
# camera_0_progress (00:05:16): 819 / 919 seconds (89.1 %)
# camera_3_progress (00:05:16): 818 / 918 seconds (89.1 %)
# camera_1_progress (00:05:17): 821 / 918 seconds (89.4 %)
# camera_2_progress (00:05:17): 821 / 918 seconds (89.4 %)
# camera_0_progress (00:05:17): 822 / 919 seconds (89.4 %)
# camera_3_progress (00:05:17): 821 / 918 seconds (89.4 %)
# camera_2_progress (00:05:18): 824 / 918 seconds (89.8 %)
# camera_3_progress (00:05:18): 823 / 918 seconds (89.7 %)
# camera_1_progress (00:05:18): 824 / 918 seconds (89.8 %)
# camera_0_progress (00:05:18): 824 / 919 seconds (89.7 %)
# camera_2_progress (00:05:19): 826 / 918 seconds (90.0 %)
# camera_0_progress (00:05:19): 826 / 919 seconds (89.9 %)
# camera_3_progress (00:05:19): 826 / 918 seconds (90.0 %)
# camera_1_progress (00:05:19): 826 / 918 seconds (90.0 %)
# camera_2_progress (00:05:20): 828 / 918 seconds (90.2 %)
# camera_0_progress (00:05:20): 829 / 919 seconds (90.2 %)
# camera_3_progress (00:05:20): 828 / 918 seconds (90.2 %)
# camera_1_progress (00:05:20): 829 / 918 seconds (90.3 %)
# camera_1_progress (00:05:21): 831 / 918 seconds (90.5 %)
# camera_2_progress (00:05:21): 831 / 918 seconds (90.5 %)
# camera_0_progress (00:05:21): 831 / 919 seconds (90.4 %)
# camera_3_progress (00:05:21): 830 / 918 seconds (90.4 %)
# camera_3_progress (00:05:22): 833 / 918 seconds (90.7 %)
# camera_1_progress (00:05:22): 833 / 918 seconds (90.7 %)
# camera_2_progress (00:05:22): 833 / 918 seconds (90.7 %)
# camera_0_progress (00:05:22): 834 / 919 seconds (90.8 %)
# camera_3_progress (00:05:23): 835 / 918 seconds (91.0 %)
# camera_1_progress (00:05:23): 836 / 918 seconds (91.1 %)
# camera_2_progress (00:05:23): 836 / 918 seconds (91.1 %)
# camera_0_progress (00:05:23): 836 / 919 seconds (91.0 %)
# camera_3_progress (00:05:24): 838 / 918 seconds (91.3 %)
# camera_1_progress (00:05:24): 838 / 918 seconds (91.3 %)
# camera_2_progress (00:05:24): 838 / 918 seconds (91.3 %)
# camera_0_progress (00:05:24): 839 / 919 seconds (91.3 %)
# camera_0_progress (00:05:25): 841 / 919 seconds (91.5 %)
# camera_3_progress (00:05:25): 840 / 918 seconds (91.5 %)
# camera_1_progress (00:05:25): 841 / 918 seconds (91.6 %)
# camera_2_progress (00:05:25): 840 / 918 seconds (91.5 %)
# camera_1_progress (00:05:26): 843 / 918 seconds (91.8 %)
# camera_2_progress (00:05:26): 843 / 918 seconds (91.8 %)
# camera_0_progress (00:05:26): 843 / 919 seconds (91.7 %)
# camera_3_progress (00:05:26): 842 / 918 seconds (91.7 %)
# camera_1_progress (00:05:27): 846 / 918 seconds (92.2 %)
# camera_2_progress (00:05:27): 845 / 918 seconds (92.0 %)
# camera_0_progress (00:05:27): 846 / 919 seconds (92.1 %)
# camera_3_progress (00:05:27): 845 / 918 seconds (92.0 %)
# camera_2_progress (00:05:28): 848 / 918 seconds (92.4 %)
# camera_0_progress (00:05:28): 848 / 919 seconds (92.3 %)
# camera_3_progress (00:05:28): 847 / 918 seconds (92.3 %)
# camera_1_progress (00:05:28): 848 / 918 seconds (92.4 %)
# camera_2_progress (00:05:29): 850 / 918 seconds (92.6 %)
# camera_0_progress (00:05:29): 851 / 919 seconds (92.6 %)
# camera_3_progress (00:05:29): 850 / 918 seconds (92.6 %)
# camera_1_progress (00:05:29): 851 / 918 seconds (92.7 %)
# camera_1_progress (00:05:30): 853 / 918 seconds (92.9 %)
# camera_2_progress (00:05:30): 853 / 918 seconds (92.9 %)
# camera_0_progress (00:05:30): 853 / 919 seconds (92.8 %)
# camera_3_progress (00:05:30): 853 / 918 seconds (92.9 %)
# camera_1_progress (00:05:31): 856 / 918 seconds (93.2 %)
# camera_2_progress (00:05:31): 856 / 918 seconds (93.2 %)
# camera_0_progress (00:05:31): 856 / 919 seconds (93.1 %)
# camera_3_progress (00:05:31): 855 / 918 seconds (93.1 %)
# camera_1_progress (00:05:32): 858 / 918 seconds (93.5 %)
# camera_2_progress (00:05:32): 858 / 918 seconds (93.5 %)
# camera_0_progress (00:05:32): 859 / 919 seconds (93.5 %)
# camera_3_progress (00:05:32): 858 / 918 seconds (93.5 %)
# camera_3_progress (00:05:33): 860 / 918 seconds (93.7 %)
# camera_1_progress (00:05:33): 861 / 918 seconds (93.8 %)
# camera_2_progress (00:05:45): 891 / 918 seconds (97.1 %)
# camera_0_progress (00:05:45): 891 / 919 seconds (97.0 %)
# camera_3_progress (00:05:45): 891 / 918 seconds (97.1 %)
# camera_1_progress (00:05:45): 891 / 918 seconds (97.1 %)
# camera_3_progress (00:05:46): 893 / 918 seconds (97.3 %)
# camera_1_progress (00:05:46): 894 / 918 seconds (97.4 %)
# camera_2_progress (00:05:46): 893 / 918 seconds (97.3 %)
# camera_0_progress (00:05:46): 894 / 919 seconds (97.3 %)
# camera_1_progress (00:05:47): 897 / 918 seconds (97.7 %)
# camera_2_progress (00:05:47): 896 / 918 seconds (97.6 %)
# camera_0_progress (00:05:47): 897 / 919 seconds (97.6 %)
# camera_3_progress (00:05:47): 896 / 918 seconds (97.6 %)
# camera_3_progress (00:05:48): 899 / 918 seconds (97.9 %)
# camera_1_progress (00:05:48): 900 / 918 seconds (98.0 %)
# camera_2_progress (00:05:48): 899 / 918 seconds (97.9 %)
# camera_0_progress (00:05:48): 900 / 919 seconds (97.9 %)
# camera_0_progress (00:05:49): 902 / 919 seconds (98.2 %)
# camera_3_progress (00:05:49): 901 / 918 seconds (98.1 %)
# camera_1_progress (00:05:49): 902 / 918 seconds (98.3 %)
# camera_2_progress (00:05:49): 902 / 918 seconds (98.3 %)
# camera_2_progress (00:05:50): 905 / 918 seconds (98.6 %)
# camera_0_progress (00:05:50): 906 / 919 seconds (98.6 %)
# camera_3_progress (00:05:50): 905 / 918 seconds (98.6 %)
# camera_1_progress (00:05:50): 906 / 918 seconds (98.7 %)
# camera_3_progress (00:05:51): 908 / 918 seconds (98.9 %)
# camera_1_progress (00:05:51): 909 / 918 seconds (99.0 %)
# camera_2_progress (00:05:51): 909 / 918 seconds (99.0 %)
# camera_0_progress (00:05:51): 909 / 919 seconds (98.9 %)
# camera_1_progress (00:05:52): 912 / 918 seconds (99.3 %)
# camera_2_progress (00:05:52): 912 / 918 seconds (99.3 %)
# camera_0_progress (00:05:52): 913 / 919 seconds (99.3 %)
# camera_3_progress (00:05:52): 912 / 918 seconds (99.3 %)
# camera_3_progress (00:05:53): 914 / 918 seconds (99.6 %)
# camera_1_progress (00:05:53): 915 / 918 seconds (99.7 %)
# camera_2_progress (00:05:53): 915 / 918 seconds (99.7 %)
# camera_0_progress (00:05:53): 915 / 919 seconds (99.6 %)
# camera_0_progress (00:05:54): 918 / 919 seconds (99.9 %)
# camera_3_progress (00:05:54): 918 / 918 seconds (100.0 %)
# camera_1_progress (00:05:54): 918 / 918 seconds (100.0 %)
# camera_3_progress (00:05:54): 918 / 918 seconds (100.0 %)
# camera_2_progress (00:05:54): 918 / 918 seconds (100.0 %)
# camera_2_progress (00:05:54): 918 / 918 seconds (100.0 %)
# camera_0_progress (00:05:54): 919 / 919 seconds (100.0 %)
# camera_1_progress (00:05:54): 918 / 918 seconds (100.0 %)
# Pipeline camera_1 finished.
# Pipeline camera_0 finished.
# Pipeline camera_2 finished.
# Pipeline camera_3 finished.
